# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(0, datetime.datetime(2018, 11, 14, 0, 3, 22, 796000), '95', 'paid', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', '411', 'Winston-Salem, NC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"'),
#  (11, datetime.datetime(2018, 11, 14, 0, 42, 13, 796000), '9', 'free', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', '551', 'Eureka-Arcata-Fortuna, CA', 'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko'),
#  (19, datetime.datetime(2018, 11, 14, 2, 57, 45, 796000), '80', 'paid', 'SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', '548', 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('10', 'Sylvie', 'Cruz', 'F', 'free'),
#  ('99', 'Ann', 'Banks', 'F', 'free'),
#  ('59', 'Lily', 'Cooper', 'F', 'free'),
#  ('95', 'Sara', 'Johnson', 'F', 'paid'),
#  ('9', 'Wyatt', 'Scott', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.932),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, 218.775),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0, 177.475),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, 267.702),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266.396)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', 'NaN', 'NaN'),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', '35.21962', '-80.01955'),
#  ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', 'NaN', 'NaN'),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', 'NaN', 'NaN'),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', 'NaN', 'NaN')]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 14, 0, 3, 22, 796000), 0, 14, 46, 11, 2018, '2'),
#  (datetime.datetime(2018, 11, 14, 0, 6, 8, 796000), 0, 14, 46, 11, 2018, '2'),
#  (datetime.datetime(2018, 11, 14, 0, 11, 6, 796000), 0, 14, 46, 11, 2018, '2'),
#  (datetime.datetime(2018, 11, 14, 0, 17, 37, 796000), 0, 14, 46, 11, 2018, '2'),
#  (datetime.datetime(2018, 11, 14, 0, 20, 25, 796000), 0, 14, 46, 11, 2018, '2')]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql select s.title, a.artist_name, s.duration from  songs s, artists a where s.artist_id = a.artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [("I Didn't Mean To", 'Casual', 218.932),
#  ('Young Boy Blues', 'JennyAnyKind', 218.775),
#  ('Amor De Cabaret', 'Sonora Santanera', 177.475),
#  ('The Moon And I (Ordinary Day Album Version)', 'Jeff And Sheri Easter', 267.702),
#  ('Insatiable (Instrumental Version)', 'Clp', 266.396),
#  ('Pink World', 'Planet P Project', 269.818),
#  ('Keepin It Real (Skit)', 'Rated R', 114.782),
#  ('Drop of Rain', 'Tweeterfriendly Music', 189.57),
#  ('Face the Ashes', 'Gob', 209.606),
#  ('Something Girls', 'Adam Ant', 233.404),
#  ('Soul Deep', 'The Box Tops', 148.035),
#  ('The Urgency (LP Version)', 'Wayne Watson', 245.211),
#  ('Tonight Will Be Alright', 'Lionel Richie', 307.382),
#  ('Auguri Cha Cha', 'Bob Azzam', 191.843),
#  ('Caught In A Dream', 'Tesla', 290.298),
#  ('Broken-Down Merry-Go-Round', 'Jimmy Wakely', 151.849),
#  ('Kassie Jones', 'Alice Stuart', 220.786),
#  ('Synthetic Dream', 'lextrical', 165.694),
# ...

# %%
# %sql SELECT COUNT(songplay_id) as plays, level from songplays group by level
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 2 rows affected.
# [(77, 'free'), (19, 'paid')]

# %%
# %sql select s.title, a.artist_name, count(sp.*) as plays from (songplays sp join songs s on sp.song_id=s.song_id) join artists a on sp.artist_id=a.artist_id group by title, artist_name
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [("I Didn't Mean To", 'Casual', 96)]
